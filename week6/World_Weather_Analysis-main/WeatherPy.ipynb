# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from config import weather_api_key
import requests

# %%
#Create set of random latittude and longitude combinations
latitude = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
longitude = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(latitude, longitude)
lat_lngs

# %%
#add the liatitudes and longitudes to a list
coordinates = list(lat_lngs)
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 626

# %%
city_data = []
print("Data Retrieval    ")
print("------------------")

record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(len(city_data))
# Out:
# Data Retrieval
# ------------------
# Processing Record 1 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 1 | saint-leu
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | solnechnyy
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | kanniyakumari
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | merauke
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | laguna
# Processing Record 25 of Set 1 | tias
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | seoul
# Processing Record 29 of Set 1 | tilichiki
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | bandarbeyla
# Processing Record 32 of Set 1 | sembe
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | roscommon
# Processing Record 35 of Set 1 | san cristobal
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | nome
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | samoded
# Processing Record 42 of Set 1 | isangel
# Processing Record 43 of Set 1 | bubaque
# Processing Record 44 of Set 1 | adrar
# Processing Record 45 of Set 1 | abu kamal
# Processing Record 46 of Set 1 | tual
# Processing Record 47 of Set 1 | higuey
# City not found. Skipping...
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | brigantine
# Processing Record 50 of Set 1 | monmouth
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | dunedin
# Processing Record 4 of Set 2 | negombo
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | lavrentiya
# Processing Record 7 of Set 2 | storslett
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | kibuye
# Processing Record 10 of Set 2 | kambove
# Processing Record 11 of Set 2 | broome
# Processing Record 12 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 2 | klaksvik
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | beihai
# Processing Record 21 of Set 2 | vila velha
# Processing Record 22 of Set 2 | kaitangata
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | daru
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | hanmer springs
# Processing Record 29 of Set 2 | neiafu
# Processing Record 30 of Set 2 | santiago de chuco
# Processing Record 31 of Set 2 | hualmay
# Processing Record 32 of Set 2 | lorengau
# Processing Record 33 of Set 2 | west wendover
# Processing Record 34 of Set 2 | samarai
# Processing Record 35 of Set 2 | half moon bay
# Processing Record 36 of Set 2 | kizukuri
# Processing Record 37 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | pochutla
# Processing Record 40 of Set 2 | vestmanna
# Processing Record 41 of Set 2 | tautira
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | bathsheba
# Processing Record 44 of Set 2 | chynov
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | thaba-tseka
# Processing Record 48 of Set 2 | ibate
# Processing Record 49 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 2 | hokitika
# Processing Record 1 of Set 3 | port blair
# Processing Record 2 of Set 3 | codrington
# Processing Record 3 of Set 3 | maturin
# Processing Record 4 of Set 3 | cape canaveral
# Processing Record 5 of Set 3 | saint-augustin
# Processing Record 6 of Set 3 | crateus
# Processing Record 7 of Set 3 | reconquista
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | sitka
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | naze
# Processing Record 14 of Set 3 | vanimo
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | snasa
# Processing Record 17 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 3 | comodoro rivadavia
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | san lawrenz
# Processing Record 21 of Set 3 | batagay-alyta
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | damghan
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | mosquera
# Processing Record 26 of Set 3 | srandakan
# Processing Record 27 of Set 3 | surt
# Processing Record 28 of Set 3 | mana
# Processing Record 29 of Set 3 | marsh harbour
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | aliquippa
# Processing Record 32 of Set 3 | peniche
# Processing Record 33 of Set 3 | campbellsville
# Processing Record 34 of Set 3 | longyearbyen
# Processing Record 35 of Set 3 | opuwo
# Processing Record 36 of Set 3 | haines junction
# Processing Record 37 of Set 3 | mumford
# Processing Record 38 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 3 | rocha
# Processing Record 40 of Set 3 | rebrikha
# Processing Record 41 of Set 3 | santa cruz de tenerife
# Processing Record 42 of Set 3 | sarny
# Processing Record 43 of Set 3 | traverse city
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | birjand
# Processing Record 46 of Set 3 | vigeland
# Processing Record 47 of Set 3 | chuy
# Processing Record 48 of Set 3 | jining
# Processing Record 49 of Set 3 | hunchun
# Processing Record 50 of Set 3 | javornik
# Processing Record 1 of Set 4 | taldan
# Processing Record 2 of Set 4 | komsomolskiy
# Processing Record 3 of Set 4 | bilma
# Processing Record 4 of Set 4 | rio gallegos
# Processing Record 5 of Set 4 | dibaya
# City not found. Skipping...
# Processing Record 6 of Set 4 | ilo
# Processing Record 7 of Set 4 | martapura
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | wichita falls
# Processing Record 10 of Set 4 | mahebourg
# Processing Record 11 of Set 4 | barrow
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | mineros
# Processing Record 14 of Set 4 | sola
# Processing Record 15 of Set 4 | puerto ayora
# Processing Record 16 of Set 4 | coquimbo
# Processing Record 17 of Set 4 | nouadhibou
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | bantry
# Processing Record 21 of Set 4 | likasi
# Processing Record 22 of Set 4 | nemuro
# Processing Record 23 of Set 4 | sechura
# Processing Record 24 of Set 4 | iracoubo
# Processing Record 25 of Set 4 | kapit
# Processing Record 26 of Set 4 | faanui
# Processing Record 27 of Set 4 | skuodas
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | arenapolis
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | saint-philippe
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | gushikawa
# Processing Record 34 of Set 4 | margate
# Processing Record 35 of Set 4 | camargo
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 4 | kalmunai
# Processing Record 39 of Set 4 | cosala
# Processing Record 40 of Set 4 | karratha
# Processing Record 41 of Set 4 | arinos
# Processing Record 42 of Set 4 | ostrovnoy
# Processing Record 43 of Set 4 | neyveli
# Processing Record 44 of Set 4 | iqaluit
# Processing Record 45 of Set 4 | georgetown
# Processing Record 46 of Set 4 | kaka
# Processing Record 47 of Set 4 | otane
# Processing Record 48 of Set 4 | roma
# Processing Record 49 of Set 4 | aquiraz
# Processing Record 50 of Set 4 | vestmannaeyjar
# Processing Record 1 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 5 | monte alegre
# Processing Record 3 of Set 5 | hami
# Processing Record 4 of Set 5 | henties bay
# Processing Record 5 of Set 5 | djibo
# Processing Record 6 of Set 5 | millinocket
# Processing Record 7 of Set 5 | hovd
# Processing Record 8 of Set 5 | novobelokatay
# Processing Record 9 of Set 5 | ghorawal
# Processing Record 10 of Set 5 | aswan
# Processing Record 11 of Set 5 | sao felix do xingu
# Processing Record 12 of Set 5 | pedernales
# Processing Record 13 of Set 5 | kabo
# Processing Record 14 of Set 5 | leningradskiy
# Processing Record 15 of Set 5 | kytlym
# City not found. Skipping...
# Processing Record 16 of Set 5 | salalah
# Processing Record 17 of Set 5 | kutum
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | yumen
# Processing Record 20 of Set 5 | coolum beach
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | college
# Processing Record 23 of Set 5 | saint-raymond
# Processing Record 24 of Set 5 | yacuiba
# Processing Record 25 of Set 5 | iskateley
# Processing Record 26 of Set 5 | jumla
# Processing Record 27 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 5 | atar
# Processing Record 29 of Set 5 | tuktoyaktuk
# Processing Record 30 of Set 5 | thompson
# Processing Record 31 of Set 5 | krasnogorsk
# Processing Record 32 of Set 5 | cape town
# Processing Record 33 of Set 5 | kieta
# Processing Record 34 of Set 5 | kabinda
# Processing Record 35 of Set 5 | cherskiy
# Processing Record 36 of Set 5 | lanxi
# Processing Record 37 of Set 5 | amuntai
# Processing Record 38 of Set 5 | chingirlau
# Processing Record 39 of Set 5 | kasempa
# Processing Record 40 of Set 5 | governador valadares
# Processing Record 41 of Set 5 | voh
# Processing Record 42 of Set 5 | ilheus
# Processing Record 43 of Set 5 | cervo
# Processing Record 44 of Set 5 | bethel
# Processing Record 45 of Set 5 | mabaruma
# Processing Record 46 of Set 5 | bardiyah
# Processing Record 47 of Set 5 | acarau
# Processing Record 48 of Set 5 | maraba
# Processing Record 49 of Set 5 | puqi
# Processing Record 50 of Set 5 | aranda de duero
# Processing Record 1 of Set 6 | sa kaeo
# Processing Record 2 of Set 6 | prieska
# Processing Record 3 of Set 6 | kahului
# Processing Record 4 of Set 6 | rundu
# Processing Record 5 of Set 6 | ahipara
# Processing Record 6 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 6 | vardo
# Processing Record 8 of Set 6 | lompoc
# Processing Record 9 of Set 6 | westport
# Processing Record 10 of Set 6 | salinopolis
# Processing Record 11 of Set 6 | sao joao da barra
# Processing Record 12 of Set 6 | calabozo
# Processing Record 13 of Set 6 | thunder bay
# Processing Record 14 of Set 6 | hambantota
# Processing Record 15 of Set 6 | anori
# Processing Record 16 of Set 6 | severo-kurilsk
# Processing Record 17 of Set 6 | naberera
# Processing Record 18 of Set 6 | ishigaki
# Processing Record 19 of Set 6 | novaya bryan
# Processing Record 20 of Set 6 | yorosso
# Processing Record 21 of Set 6 | marzuq
# Processing Record 22 of Set 6 | arman
# Processing Record 23 of Set 6 | ordzhonikidze
# Processing Record 24 of Set 6 | basco
# Processing Record 25 of Set 6 | gubkinskiy
# Processing Record 26 of Set 6 | eydhafushi
# Processing Record 27 of Set 6 | pevek
# Processing Record 28 of Set 6 | starkville
# Processing Record 29 of Set 6 | kununurra
# Processing Record 30 of Set 6 | ancud
# Processing Record 31 of Set 6 | clyde river
# Processing Record 32 of Set 6 | viking
# Processing Record 33 of Set 6 | puerto carreno
# Processing Record 34 of Set 6 | saint george
# Processing Record 35 of Set 6 | lindenberg
# Processing Record 36 of Set 6 | kaisiadorys
# Processing Record 37 of Set 6 | maracaibo
# Processing Record 38 of Set 6 | yining
# Processing Record 39 of Set 6 | sur
# Processing Record 40 of Set 6 | berdigestyakh
# Processing Record 41 of Set 6 | geraldton
# Processing Record 42 of Set 6 | grindavik
# Processing Record 43 of Set 6 | tenango
# Processing Record 44 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 6 | esperance
# Processing Record 46 of Set 6 | rethimnon
# Processing Record 47 of Set 6 | isla mujeres
# Processing Record 48 of Set 6 | bataipora
# Processing Record 49 of Set 6 | goderich
# Processing Record 50 of Set 6 | loandjili
# Processing Record 1 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 2 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 4 of Set 7 | kapoeta
# Processing Record 5 of Set 7 | carnarvon
# Processing Record 6 of Set 7 | vasterhaninge
# Processing Record 7 of Set 7 | alofi
# Processing Record 8 of Set 7 | ponta do sol
# Processing Record 9 of Set 7 | bilibino
# Processing Record 10 of Set 7 | brae
# Processing Record 11 of Set 7 | pontianak
# Processing Record 12 of Set 7 | chiredzi
# Processing Record 13 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 7 | esil
# Processing Record 15 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 7 | caucaia
# Processing Record 17 of Set 7 | iquique
# Processing Record 18 of Set 7 | luis correia
# Processing Record 19 of Set 7 | oranjestad
# Processing Record 20 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 7 | csorvas
# Processing Record 22 of Set 7 | pavlogradka
# Processing Record 23 of Set 7 | talcahuano
# Processing Record 24 of Set 7 | grand gaube
# Processing Record 25 of Set 7 | saldanha
# Processing Record 26 of Set 7 | olafsvik
# Processing Record 27 of Set 7 | gotsu
# Processing Record 28 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 7 | luganville
# Processing Record 30 of Set 7 | fort nelson
# Processing Record 31 of Set 7 | hasaki
# Processing Record 32 of Set 7 | neuquen
# Processing Record 33 of Set 7 | mount isa
# Processing Record 34 of Set 7 | ararangua
# Processing Record 35 of Set 7 | yuanping
# Processing Record 36 of Set 7 | salta
# Processing Record 37 of Set 7 | norman wells
# Processing Record 38 of Set 7 | lewiston
# Processing Record 39 of Set 7 | teshie
# Processing Record 40 of Set 7 | orlik
# Processing Record 41 of Set 7 | morgan city
# Processing Record 42 of Set 7 | kudahuvadhoo
# Processing Record 43 of Set 7 | liverpool
# Processing Record 44 of Set 7 | ube
# Processing Record 45 of Set 7 | igarka
# Processing Record 46 of Set 7 | cocorit
# Processing Record 47 of Set 7 | road town
# Processing Record 48 of Set 7 | aktau
# Processing Record 49 of Set 7 | riyadh
# Processing Record 50 of Set 7 | sandwick
# Processing Record 1 of Set 8 | kedrovyy
# Processing Record 2 of Set 8 | challapata
# Processing Record 3 of Set 8 | bay-khaak
# Processing Record 4 of Set 8 | san javier
# Processing Record 5 of Set 8 | lerwick
# Processing Record 6 of Set 8 | valparaiso
# Processing Record 7 of Set 8 | shelburne
# Processing Record 8 of Set 8 | muroto
# Processing Record 9 of Set 8 | ngaoundere
# Processing Record 10 of Set 8 | greenwood
# Processing Record 11 of Set 8 | conakry
# Processing Record 12 of Set 8 | kurumkan
# Processing Record 13 of Set 8 | aksha
# Processing Record 14 of Set 8 | abbeville
# Processing Record 15 of Set 8 | north platte
# Processing Record 16 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 8 | nhulunbuy
# Processing Record 18 of Set 8 | husavik
# Processing Record 19 of Set 8 | khuzhir
# Processing Record 20 of Set 8 | fairbanks
# Processing Record 21 of Set 8 | rovira
# Processing Record 22 of Set 8 | saint-raphael
# Processing Record 23 of Set 8 | vila franca do campo
# Processing Record 24 of Set 8 | okhotsk
# Processing Record 25 of Set 8 | nedjo
# Processing Record 26 of Set 8 | prince rupert
# Processing Record 27 of Set 8 | pizarro
# Processing Record 28 of Set 8 | hofn
# Processing Record 29 of Set 8 | davila
# Processing Record 30 of Set 8 | chivolo
# Processing Record 31 of Set 8 | sinop
# Processing Record 32 of Set 8 | baruun-urt
# Processing Record 33 of Set 8 | shuangcheng
# Processing Record 34 of Set 8 | scottsbluff
# Processing Record 35 of Set 8 | tarakan
# Processing Record 36 of Set 8 | puerto madryn
# Processing Record 37 of Set 8 | mago
# Processing Record 38 of Set 8 | zhigansk
# Processing Record 39 of Set 8 | ilulissat
# Processing Record 40 of Set 8 | kirakira
# Processing Record 41 of Set 8 | along
# Processing Record 42 of Set 8 | dingzhou
# Processing Record 43 of Set 8 | prado
# Processing Record 44 of Set 8 | beloha
# Processing Record 45 of Set 8 | kavaratti
# Processing Record 46 of Set 8 | sunland park
# Processing Record 47 of Set 8 | luangwa
# Processing Record 48 of Set 8 | tilaran
# Processing Record 49 of Set 8 | kabelvag
# Processing Record 50 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 1 of Set 9 | hit
# Processing Record 2 of Set 9 | necochea
# Processing Record 3 of Set 9 | te anau
# Processing Record 4 of Set 9 | lagos
# Processing Record 5 of Set 9 | tsiroanomandidy
# Processing Record 6 of Set 9 | kemijarvi
# Processing Record 7 of Set 9 | disna
# Processing Record 8 of Set 9 | tucuman
# Processing Record 9 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 9 | alyangula
# Processing Record 11 of Set 9 | awjilah
# Processing Record 12 of Set 9 | teonthar
# Processing Record 13 of Set 9 | nantucket
# Processing Record 14 of Set 9 | srednekolymsk
# Processing Record 15 of Set 9 | cayenne
# Processing Record 16 of Set 9 | elk city
# Processing Record 17 of Set 9 | chirongui
# Processing Record 18 of Set 9 | rio grande
# Processing Record 19 of Set 9 | bemidji
# Processing Record 20 of Set 9 | biak
# Processing Record 21 of Set 9 | shingu
# Processing Record 22 of Set 9 | mbanza-ngungu
# Processing Record 23 of Set 9 | state college
# Processing Record 24 of Set 9 | nishihara
# Processing Record 25 of Set 9 | lata
# Processing Record 26 of Set 9 | airai
# Processing Record 27 of Set 9 | taltal
# Processing Record 28 of Set 9 | konstantinovskaya
# Processing Record 29 of Set 9 | esfarayen
# Processing Record 30 of Set 9 | playas
# Processing Record 31 of Set 9 | la rioja
# Processing Record 32 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 33 of Set 9 | vangaindrano
# Processing Record 34 of Set 9 | zima
# Processing Record 35 of Set 9 | zvenyhorodka
# Processing Record 36 of Set 9 | khorinsk
# Processing Record 37 of Set 9 | kensington
# Processing Record 38 of Set 9 | krasnovishersk
# Processing Record 39 of Set 9 | quatre cocos
# Processing Record 40 of Set 9 | deputatskiy
# Processing Record 41 of Set 9 | rapid valley
# Processing Record 42 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 43 of Set 9 | charters towers
# Processing Record 44 of Set 9 | san juan bautista
# Processing Record 45 of Set 9 | caravelas
# Processing Record 46 of Set 9 | srikakulam
# Processing Record 47 of Set 9 | kholm-zhirkovskiy
# Processing Record 48 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 9 | okha
# Processing Record 50 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 10 | shumyachi
# Processing Record 2 of Set 10 | kodinar
# Processing Record 3 of Set 10 | itarema
# Processing Record 4 of Set 10 | kiunga
# Processing Record 5 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 10 | portland
# Processing Record 7 of Set 10 | bandar-e lengeh
# Processing Record 8 of Set 10 | wanning
# Processing Record 9 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 10 | high level
# Processing Record 11 of Set 10 | ammon
# Processing Record 12 of Set 10 | oussouye
# Processing Record 13 of Set 10 | cotonou
# Processing Record 14 of Set 10 | victoria
# Processing Record 15 of Set 10 | novaya lyada
# Processing Record 16 of Set 10 | san pedro
# Processing Record 17 of Set 10 | tobermory
# Processing Record 18 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 10 | sakaiminato
# Processing Record 20 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 10 | guerrero negro
# Processing Record 22 of Set 10 | nipawin
# Processing Record 23 of Set 10 | vostochnyy
# Processing Record 24 of Set 10 | kungurtug
# Processing Record 25 of Set 10 | tuatapere
# Processing Record 26 of Set 10 | nortelandia
# Processing Record 27 of Set 10 | taboga
# Processing Record 28 of Set 10 | ormara
# Processing Record 29 of Set 10 | majene
# Processing Record 30 of Set 10 | amberley
# Processing Record 31 of Set 10 | yurimaguas
# Processing Record 32 of Set 10 | banyo
# Processing Record 33 of Set 10 | chunoyar
# Processing Record 34 of Set 10 | waipawa
# Processing Record 35 of Set 10 | belmonte
# Processing Record 36 of Set 10 | novonikolayevskiy
# Processing Record 37 of Set 10 | urubicha
# Processing Record 38 of Set 10 | porto uniao
# Processing Record 39 of Set 10 | viedma
# Processing Record 40 of Set 10 | burica
# City not found. Skipping...
# Processing Record 41 of Set 10 | avera
# Processing Record 42 of Set 10 | lasa
# Processing Record 43 of Set 10 | dapaong
# Processing Record 44 of Set 10 | rock sound
# Processing Record 45 of Set 10 | havoysund
# Processing Record 46 of Set 10 | vredendal
# Processing Record 47 of Set 10 | abaza
# Processing Record 48 of Set 10 | hemnesberget
# Processing Record 49 of Set 10 | santa eulalia
# Processing Record 50 of Set 10 | roura
# Processing Record 1 of Set 11 | bambanglipuro
# Processing Record 2 of Set 11 | wichita
# Processing Record 3 of Set 11 | aviles
# Processing Record 4 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 11 | dali
# Processing Record 6 of Set 11 | senanga
# Processing Record 7 of Set 11 | winslow
# Processing Record 8 of Set 11 | waingapu
# Processing Record 9 of Set 11 | lubao
# Processing Record 10 of Set 11 | temnikov
# Processing Record 11 of Set 11 | shache
# Processing Record 12 of Set 11 | manadhoo
# Processing Record 13 of Set 11 | aasiaat
# Processing Record 14 of Set 11 | niksar
# Processing Record 15 of Set 11 | garden city
# Processing Record 16 of Set 11 | la rochelle
# Processing Record 17 of Set 11 | arlit
# Processing Record 18 of Set 11 | baykit
# Processing Record 19 of Set 11 | pueblo nuevo
# Processing Record 20 of Set 11 | owando
# Processing Record 21 of Set 11 | rayachoti
# Processing Record 22 of Set 11 | jinchang
# Processing Record 23 of Set 11 | namibe
# Processing Record 24 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 11 | yayva
# Processing Record 26 of Set 11 | babati
# Processing Record 27 of Set 11 | plouzane
# Processing Record 28 of Set 11 | hanyang
# Processing Record 29 of Set 11 | chulman
# Processing Record 30 of Set 11 | richards bay
# Processing Record 31 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 11 | mattawa
# Processing Record 33 of Set 11 | madang
# Processing Record 34 of Set 11 | aliwal north
# Processing Record 35 of Set 11 | zhigalovo
# Processing Record 36 of Set 11 | raposos
# Processing Record 37 of Set 11 | gisborne
# Processing Record 38 of Set 11 | puerto suarez
# Processing Record 39 of Set 11 | santa fe
# Processing Record 40 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 11 | le havre
# Processing Record 42 of Set 11 | kristiinankaupunki
# Processing Record 43 of Set 11 | bururi
# Processing Record 44 of Set 11 | guipavas
# Processing Record 45 of Set 11 | zalantun
# Processing Record 46 of Set 11 | waw
# Processing Record 47 of Set 11 | usinsk
# Processing Record 48 of Set 11 | valle de allende
# Processing Record 49 of Set 11 | gobabis
# Processing Record 50 of Set 11 | coihaique
# Processing Record 1 of Set 12 | kholodnyy
# Processing Record 2 of Set 12 | cruzeiro do sul
# Processing Record 3 of Set 12 | guabito
# Processing Record 4 of Set 12 | san vicente
# Processing Record 5 of Set 12 | la ronge
# Processing Record 6 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 12 | mindelo
# Processing Record 8 of Set 12 | dauphin
# Processing Record 9 of Set 12 | ponta delgada
# Processing Record 10 of Set 12 | atbasar
# Processing Record 11 of Set 12 | valreas
# Processing Record 12 of Set 12 | teacapan
# Processing Record 13 of Set 12 | krasnoselkup
# Processing Record 14 of Set 12 | taber
# Processing Record 15 of Set 12 | esna
# Processing Record 16 of Set 12 | plettenberg bay
# Processing Record 17 of Set 12 | madarounfa
# Processing Record 18 of Set 12 | chumikan
# Processing Record 19 of Set 12 | walvis bay
# Processing Record 20 of Set 12 | nacala
# Processing Record 21 of Set 12 | chapais
# Processing Record 22 of Set 12 | antsohihy
# Processing Record 23 of Set 12 | polunochnoye
# Processing Record 24 of Set 12 | ambilobe
# Processing Record 25 of Set 12 | xiamen
# Processing Record 26 of Set 12 | kaman
# Processing Record 27 of Set 12 | las juntas
# Processing Record 28 of Set 12 | gornopravdinsk
# Processing Record 29 of Set 12 | narsaq
# Processing Record 30 of Set 12 | victor harbor
# Processing Record 31 of Set 12 | pantai remis
# Processing Record 32 of Set 12 | hukuntsi
# Processing Record 33 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 12 | puerto leguizamo
# Processing Record 35 of Set 12 | vagur
# Processing Record 36 of Set 12 | bay roberts
# Processing Record 37 of Set 12 | wiwili
# Processing Record 38 of Set 12 | fukue
# Processing Record 39 of Set 12 | tomatlan
# Processing Record 40 of Set 12 | adeje
# Processing Record 41 of Set 12 | goya
# Processing Record 42 of Set 12 | angra
# City not found. Skipping...
# Processing Record 43 of Set 12 | nizwa
# Processing Record 44 of Set 12 | maki
# Processing Record 45 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 12 | leesburg
# Processing Record 47 of Set 12 | farmington
# Processing Record 48 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 49 of Set 12 | santa cruz
# Processing Record 50 of Set 12 | kuhdasht
# Processing Record 1 of Set 13 | sabang
# Processing Record 2 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 13 | kupang
# Processing Record 4 of Set 13 | dobryanka
# Processing Record 5 of Set 13 | kushiro
# Processing Record 6 of Set 13 | sibolga
# Processing Record 7 of Set 13 | agua branca
# Processing Record 8 of Set 13 | ketchikan
# Processing Record 9 of Set 13 | syamzha
# Processing Record 10 of Set 13 | great yarmouth
# Processing Record 11 of Set 13 | luau
# Processing Record 12 of Set 13 | shymkent
# Processing Record 13 of Set 13 | muncar
# Processing Record 14 of Set 13 | omboue
# Processing Record 15 of Set 13 | hatta
# Processing Record 16 of Set 13 | hay river
# Processing Record 17 of Set 13 | tazovskiy
# Processing Record 18 of Set 13 | drexel heights
# Processing Record 19 of Set 13 | neftcala
# Processing Record 20 of Set 13 | erzin
# Processing Record 21 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 22 of Set 13 | karagaylinskiy
# Processing Record 23 of Set 13 | bud
# Processing Record 24 of Set 13 | ayios kirikos
# City not found. Skipping...
# Processing Record 25 of Set 13 | puerto escondido
# Processing Record 26 of Set 13 | princeton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 572

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(4)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Saint-Leu -21.1500   55.2833     78.80        57           0        3.44
# 1     Ushuaia -54.8000  -68.3000     55.40        44          40       16.11
# 2  Solnechnyy  50.7214  136.6319    -12.12        80         100        2.77
# 3        Hilo  19.7297 -155.0900     77.00        69          40        5.75
#
#   Country                 Date
# 0      RE  2021-01-09 03:19:03
# 1      AR  2021-01-09 03:19:03
# 2      RU  2021-01-09 03:19:04
# 3      US  2021-01-09 03:17:22

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
new_city_data_df_order =city_data_df[new_column_order]
new_city_data_df_order.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0      Saint-Leu      RE  2021-01-09 03:19:03 -21.1500   55.2833     78.80
# 1        Ushuaia      AR  2021-01-09 03:19:03 -54.8000  -68.3000     55.40
# 2     Solnechnyy      RU  2021-01-09 03:19:04  50.7214  136.6319    -12.12
# 3           Hilo      US  2021-01-09 03:17:22  19.7297 -155.0900     77.00
# 4  Kanniyakumari      IN  2021-01-09 03:19:04   8.0833   77.5667     80.06
# 5          Tiksi      RU  2021-01-09 03:19:04  71.6872  128.8694    -14.28
# 6      Jamestown      US  2021-01-09 03:19:04  42.0970  -79.2353     21.99
# 7     Butaritari      KI  2021-01-09 03:19:05   3.0707  172.7902     80.96
# 8   Port Lincoln      AU  2021-01-09 03:19:05 -34.7333  135.8667     78.21
# 9       Khatanga      RU  2021-01-09 03:19:05  71.9667  102.5000    -18.06
#
#    Humidity  Cloudiness  Wind Speed
# 0        57           0        3.44
# 1        44          40       16.11
# 2        80         100        2.77
# 3        69          40        5.75
# 4        79          97       18.79
# 5        89         100       12.71
# 6        93          20        5.75
# 7        82         100       19.53
# 8        46           0        7.76
# 9        88         100        7.74

# %%
output_data_file = "weather_data/cities.csv"
city_data_df.to_csv(output_data_file,index_label="City_ID")
